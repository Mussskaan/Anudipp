# %% [markdown]
# pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load your dataset

# %%
df=pd.read_csv("onlinefoods.csv",encoding="latin-1")

# %%
df.sample(5)
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 208   25    Male         Single  Self Employeed  More than 50000
# 75    24  Female         Single         Student   25001 to 50000
# 8     23  Female         Single         Student        No Income
# 305   24  Female         Single         Student        No Income
# 384   23  Female         Single         Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 208                   Graduate            2   12.9783    77.6408    560038
# 75               Post Graduate            3   13.1020    77.5864    560064
# 8                Post Graduate            2   12.9766    77.5993    560001
# 305              Post Graduate            3   12.9828    77.6131    560042
# 384              Post Graduate            4   12.9854    77.7081    560048
#
#     Output  Feedback Unnamed: 12
# 208    Yes  Positive         Yes
# 75     Yes  Positive         Yes
# ...

# %%
df.sample(100)
# Out:
#      Age  Gender     Marital Status      Occupation   Monthly Income  \
# 218   31  Female            Married      House wife        No Income
# 381   22    Male             Single         Student        No Income
# 255   27    Male            Married  Self Employeed  More than 50000
# 17    23  Female             Single         Student        No Income
# 83    22    Male             Single         Student        No Income
# ..   ...     ...                ...             ...              ...
# 243   23  Female             Single         Student        No Income
# 294   25  Female  Prefer not to say        Employee   25001 to 50000
# 386   23    Male             Single         Student   Below Rs.10000
# 332   20    Male             Single         Student        No Income
# 145   25    Male             Single        Employee   10001 to 25000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# ...

# %%
df.head(5)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.tail(5)
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.sample(25)
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 93    24  Female         Single         Student        No Income
# 159   20  Female         Single         Student        No Income
# 169   20    Male         Single         Student        No Income
# 46    24  Female         Single         Student        No Income
# 204   25  Female         Single         Student        No Income
# 322   29    Male         Single        Employee   25001 to 50000
# 278   30    Male        Married        Employee  More than 50000
# 217   26    Male         Single        Employee   10001 to 25000
# 353   27    Male        Married  Self Employeed   25001 to 50000
# 183   22    Male         Single         Student        No Income
# 112   25    Male         Single         Student   Below Rs.10000
# 133   19    Male         Single         Student        No Income
# 147   24  Female         Single         Student        No Income
# ...

# %%
#female order more online food than male
#single has positive feedback than negative
#post graduate students order more than graduate students
#single  people order more than married ones
#age group from 20 to 25 orders more online food
#which pincode creates more positive feedback

# %%
df["Age"]
# Out:
# 0      20
# 1      24
# 2      22
# 3      22
# 4      22
#        ..
# 383    23
# 384    23
# 385    22
# 386    23
# 387    23
# Name: Age, Length: 388, dtype: int64

# %%
df["Monthly Income"]
# Out:
# 0           No Income
# 1      Below Rs.10000
# 2      Below Rs.10000
# 3           No Income
# 4      Below Rs.10000
#             ...
# 383         No Income
# 384         No Income
# 385         No Income
# 386    Below Rs.10000
# 387         No Income
# Name: Monthly Income, Length: 388, dtype: object

# %%
df["Educational Qualifications"]
# Out:
# 0      Post Graduate
# 1           Graduate
# 2      Post Graduate
# 3           Graduate
# 4      Post Graduate
#            ...
# 383    Post Graduate
# 384    Post Graduate
# 385    Post Graduate
# 386    Post Graduate
# 387    Post Graduate
# Name: Educational Qualifications, Length: 388, dtype: object

# %%
df["Age"]
# Out:
# 0      20
# 1      24
# 2      22
# 3      22
# 4      22
#        ..
# 383    23
# 384    23
# 385    22
# 386    23
# 387    23
# Name: Age, Length: 388, dtype: int64

# %%
df["Gender"]
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 383    Female
# 384    Female
# 385    Female
# 386      Male
# 387      Male
# Name: Gender, Length: 388, dtype: object

# %%
df["Family size"]
# Out:
# 0      4
# 1      3
# 2      3
# 3      6
# 4      4
#       ..
# 383    2
# 384    4
# 385    5
# 386    2
# 387    5
# Name: Family size, Length: 388, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    Age  Gender Marital Status Occupation Monthly Income  \
# 0   20  Female         Single    Student      No Income
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
#
#   Output  Feedback Unnamed: 12
# 0    Yes  Positive         Yes

# %%
df.iloc[1]
# Out:
# Age                                       24
# Gender                                Female
# Marital Status                        Single
# Occupation                           Student
# Monthly Income                Below Rs.10000
# Educational Qualifications          Graduate
# Family size                                3
# latitude                              12.977
# longitude                            77.5773
# Pin code                              560009
# Output                                   Yes
# Feedback                            Positive
# Unnamed: 12                              Yes
# Name: 1, dtype: object

# %%
df.iloc[1,2]
# Out:
# 'Single'

# %%
df.iloc[56]
# Out:
# Age                                      22
# Gender                               Female
# Marital Status                       Single
# Occupation                          Student
# Monthly Income                    No Income
# Educational Qualifications    Post Graduate
# Family size                               1
# latitude                            12.8845
# longitude                           77.6036
# Pin code                             560076
# Output                                  Yes
# Feedback                           Positive
# Unnamed: 12                             Yes
# Name: 56, dtype: object
